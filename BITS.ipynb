# %% [markdown]
# # BIRGER Project Proposal

# %% [markdown]
# This project involves the development of dynamic dashboards, real-time Analytics and AI insights through smart KPIs for BIRGER. support and service center (NOC).
#
# Our Network Operations Centre monitors the after-sales service of BIRGER. for all its customer in the region. NOC responds to our customer service and support request calls, allocates incidents to our field engineers, ensures that all incidents are addressed promptly and reports back to our customers.
#
# Our qualified and experienced engineers provide 1st and 2nd line hardware maintenance services, software maintenance, field and remote diagnostics and problem resolution, and network monitoring.
#
# BIRGER. already has an incident reporting platform for the logging and follow-up of incidents reported by our customers. The platform is two tier architecture with a frontend web base application and a backend SQL database.
#
# The main objective of this project is to leverage the existing data to design dynamic dashboards, real-time Analytics and AI insights through smart KPIs for our support and service centre (NOC) to enhance our efficiency, decision-making processes, and overall performance. Hence assisting us in providing a better proximity service for a better customer experience.

# %% [markdown]
# # IMPORTING LIBRARY

# %%
from pathlib import Path  # Python Standard Library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %%
# Read Excel Dummy data from BIRGER called SST-Report-Practicum Dummy Data.xlsx
file_path = "C:\\Users\\Savage\\Desktop\\BIRGER\\BITS-Reports Practicum Dummy Data.xlsx"
df = pd.read_excel(file_path, engine="openpyxl", sheet_name="RAW", nrows=4343)
df
# Out:
#      Created By          Reported On Created On Start Date Start Time  \
# 0        Rakesh                  NaN 2022-01-05 2022-01-12      09:15
# 1        Rakesh                  NaN 2022-01-05 2021-12-21      10:00
# 2        Rakesh                  NaN 2022-01-04 2022-01-04      10:00
# 3        Rakesh                  NaN 2022-01-05 2022-01-05      09:00
# 4        Rakesh                  NaN 2022-01-05 2021-12-28      10:00
# ...         ...                  ...        ...        ...        ...
# 4337     Rakesh  2023-08-21 00:00:00 2023-08-22        NaT        NaN
# 4338     Rakesh  2023-08-24 00:00:00 2023-08-23        NaT        NaN
# 4339     Rakesh  2023-08-23 00:00:00 2023-08-23        NaT        NaN
# 4340     Rakesh  2023-08-22 00:00:00 2023-08-23        NaT        NaN
# 4341     Rakesh  2023-08-22 00:00:00 2023-08-23        NaT        NaN
#
#                  End Date End Time Travel Time  Incident Id       Customer  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4342 entries, 0 to 4341
# Data columns (total 41 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Created By          4342 non-null   object
#  1   Reported On         3438 non-null   object
#  2   Created On          4342 non-null   datetime64[ns]
#  3   Start Date          3006 non-null   datetime64[ns]
#  4   Start Time          3006 non-null   object
#  5   End Date            3006 non-null   object
#  6   End Time            3006 non-null   object
#  7   Travel Time         4342 non-null   object
#  8   Incident Id         4342 non-null   int64
#  9   Customer            4342 non-null   object
#  10  Location            3251 non-null   object
#  11  Contract            3442 non-null   object
#  12  Priority            1806 non-null   object
#  13  SLA                 3675 non-null   object
#  14  Servicing Team      4342 non-null   object
# ...

# %%
df.isnull().sum().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of Created By               0
# Reported On            904
# Created On               0
# Start Date            1336
# Start Time            1336
# End Date              1336
# End Time              1336
# Travel Time              0
# Incident Id              0
# Customer                 0
# Location              1091
# Contract               900
# Priority              2536
# SLA                    667
# Servicing Team           0
# Category                 0
# Service Type             0
# Subject                  0
# Technician               0
# Item Id               1498
# Incident Summary         9
# Resolution Summary    1389
# Task Summary          1341
# Model No              2490
# Serial No             1521
# Unit ID               4239
# Part Number           1588
# Service Report No      918
# Task ID               1336
# Task Description      1341
# Task Type             1336
# Task Status           1336
# ...

# %%
# Interpolate missing values using forward fill ('pad')
df.interpolate(method='pad', inplace=True)

# %%
df
# Out:
#      Created By          Reported On Created On Start Date Start Time  \
# 0        Rakesh                  NaN 2022-01-05 2022-01-12      09:15
# 1        Rakesh                  NaN 2022-01-05 2021-12-21      10:00
# 2        Rakesh                  NaN 2022-01-04 2022-01-04      10:00
# 3        Rakesh                  NaN 2022-01-05 2022-01-05      09:00
# 4        Rakesh                  NaN 2022-01-05 2021-12-28      10:00
# ...         ...                  ...        ...        ...        ...
# 4337     Rakesh  2023-08-21 00:00:00 2023-08-22 2023-08-21      09:00
# 4338     Rakesh  2023-08-24 00:00:00 2023-08-23 2023-08-21      09:00
# 4339     Rakesh  2023-08-23 00:00:00 2023-08-23 2023-08-21      09:00
# 4340     Rakesh  2023-08-22 00:00:00 2023-08-23 2023-08-21      09:00
# 4341     Rakesh  2023-08-22 00:00:00 2023-08-23 2023-08-21      09:00
#
#                  End Date End Time Travel Time  Incident Id       Customer  \
# ...

# %%
df.isnull().sum().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of Created By              0
# Reported On           296
# Created On              0
# Start Date              0
# Start Time              0
# End Date                0
# End Time                0
# Travel Time             0
# Incident Id             0
# Customer                0
# Location                0
# Contract                0
# Priority                6
# SLA                     2
# Servicing Team          0
# Category                0
# Service Type            0
# Subject                 0
# Technician              0
# Item Id                 2
# Incident Summary        0
# Resolution Summary      0
# Task Summary            0
# Model No               19
# Serial No               2
# Unit ID               213
# Part Number             2
# Service Report No       0
# Task ID                 0
# Task Description        0
# Task Type               0
# Task Status             0
# Hours to be Billed      0
# ...

# %%
df.shape
# Out:
# (4342, 41)

# %%
df.columns
# Out:
# Index(['Created By', 'Reported On', 'Created On', 'Start Date', 'Start Time',
#        'End Date', 'End Time', 'Travel Time', 'Incident Id', 'Customer',
#        'Location', 'Contract', 'Priority', 'SLA', 'Servicing Team', 'Category',
#        'Service Type', 'Subject', 'Technician', 'Item Id', 'Incident Summary',
#        'Resolution Summary', 'Task Summary', 'Model No', 'Serial No',
#        'Unit ID', 'Part Number', 'Service Report No', 'Task ID',
#        'Task Description', 'Task Type', 'Task Status', 'Hours to be Billed',
#        'Status', 'Contact Person', 'Geo', 'Assignment Type', 'Day of the Week',
#        'MONTH', 'YEAR', 'Time Taken'],
#       dtype='object')

# %% [markdown]
# # Data Transformation: Convert Date and Time Columns

# %%
# # Combine date and time columns for 'Start' and 'End'
# df['Start DateTime'] = pd.to_datetime(df['Start Date'] + ' ' + df['Start Time'], format='%d/%m/%Y %H:%M', errors='coerce')
# df['End DateTime'] = pd.to_datetime(df['End Date'] + ' ' + df['End Time'], format='%d/%m/%Y %H:%M', errors='coerce')

# # Drop the original date and time columns if needed
# df.drop(['Start Date', 'Start Time', 'End Date', 'End Time'], axis=1, inplace=True)

# # Check for rows with invalid datetime values (NaT)
# invalid_rows = df[(df['Start DateTime'].isna()) | (df['End DateTime'].isna())]

# # You can handle or remove the invalid rows as needed
# df = df.dropna(subset=['Start DateTime', 'End DateTime'])

# Assuming df is your DataFrame
# Remove leading and trailing spaces from column names
df.columns = df.columns.str.strip()

# Convert 'Start Date' and 'Start Time' to strings explicitly
df['Start Date'] = df['Start Date'].astype(str)
df['Start Time'] = df['Start Time'].astype(str)

# Combine date and time columns for 'Start'
df['Start DateTime'] = pd.to_datetime(df['Start Date'] + ' ' + df['Start Time'], format='%d/%m/%Y %H:%M', errors='coerce')

# Convert 'End Date' and 'End Time' to strings explicitly
df['End Date'] = df['End Date'].astype(str)
df['End Time'] = df['End Time'].astype(str)

# Combine date and time columns for 'End'
df['End DateTime'] = pd.to_datetime(df['End Date'] + ' ' + df['End Time'], format='%d/%m/%Y %H:%M', errors='coerce')

# Drop the original date and time columns if needed
df.drop(['Start Date', 'Start Time', 'End Date', 'End Time'], axis=1, inplace=True)

# Check data types and the first few rows of the DataFrame
print("Data Types:")
print(df.dtypes)
print("First Few Rows:")
print(df.head())
# Out:
# Data Types:
# Created By                    object
# Reported On                   object
# Created On            datetime64[ns]
# Travel Time                   object
# Incident Id                    int64
# Customer                      object
# Location                      object
# Contract                      object
# Priority                      object
# SLA                           object
# Servicing Team                object
# Category                      object
# Service Type                  object
# Subject                       object
# Technician                    object
# Item Id                      float64
# Incident Summary              object
# Resolution Summary            object
# Task Summary                  object
# Model No                      object
# Serial No                     object
# Unit ID                       object
# Part Number                   object
# Service Report No             object
# Task ID                      float64
# ...

# %%
# Print the current column names
print("Current Column Names:")
print(df.columns)
# Out:
# Current Column Names:
# Index(['Created By', 'Reported On', 'Created On', 'Travel Time', 'Incident Id',
#        'Customer', 'Location', 'Contract', 'Priority', 'SLA', 'Servicing Team',
#        'Category', 'Service Type', 'Subject', 'Technician', 'Item Id',
#        'Incident Summary', 'Resolution Summary', 'Task Summary', 'Model No',
#        'Serial No', 'Unit ID', 'Part Number', 'Service Report No', 'Task ID',
#        'Task Description', 'Task Type', 'Task Status', 'Hours to be Billed',
#        'Status', 'Contact Person', 'Geo', 'Assignment Type', 'Day of the Week',
#        'MONTH', 'YEAR', 'Time Taken', 'Start DateTime', 'End DateTime'],
#       dtype='object')

# %%
# # Convert 'Start Date' and 'Start Time' to strings explicitly
# df['Start Date'] = df['Start Date'].astype(str)
# df['Start Time'] = df['Start Time'].astype(str)

# # Combine 'Start Date' and 'Start Time' into 'Start DateTime'
# df['Start DateTime'] = pd.to_datetime(df['Start Date'] + ' ' + df['Start Time'], format="%d/%m/%Y %H:%M", errors='coerce')

# # Convert 'End Date' and 'End Time' to strings explicitly
# df['End Date'] = df['End Date'].astype(str)
# df['End Time'] = df['End Time'].astype(str)

# # Combine 'End Date' and 'End Time' into 'End DateTime'
# df['End DateTime'] = pd.to_datetime(df['End Date'] + ' ' + df['End Time'], format="%d/%m/%Y %H:%M", errors='coerce')

# # Drop the original date and time columns if needed
# df.drop(['Start Date', 'Start Time', 'End Date', 'End Time'], axis=1, inplace=True)

# # Check for rows with invalid datetime values (NaT)
# invalid_rows = df[(df['Start DateTime'].isna()) | (df['End DateTime'].isna())]

# # You can handle or remove the invalid rows as needed
# df = df.dropna(subset=['Start DateTime', 'End DateTime'])

# # Display the updated DataFrame
# print("Updated DataFrame:")
# print(df[['Start DateTime', 'End DateTime']])

# %%
df
# Out:
#      Created By          Reported On Created On Travel Time  Incident Id  \
# 0        Rakesh                  NaN 2022-01-05       0:0:0       103360
# 1        Rakesh                  NaN 2022-01-05       0:0:0       103362
# 2        Rakesh                  NaN 2022-01-04       0:0:0       103324
# 3        Rakesh                  NaN 2022-01-05       0:0:0       103355
# 4        Rakesh                  NaN 2022-01-05       0:0:0       103374
# ...         ...                  ...        ...         ...          ...
# 4337     Rakesh  2023-08-21 00:00:00 2023-08-22       0:0:0       120124
# 4338     Rakesh  2023-08-24 00:00:00 2023-08-23       0:0:0       120131
# 4339     Rakesh  2023-08-23 00:00:00 2023-08-23       0:0:0       120132
# 4340     Rakesh  2023-08-22 00:00:00 2023-08-23       0:0:0       120133
# 4341     Rakesh  2023-08-22 00:00:00 2023-08-23       0:0:0       120134
#
#            Customer       Location                  Contract    Priority  \
# ...

# %%
startDate = df['Start DateTime'].min()
endDate = df['End DateTime'].max()

# %%
endDate
# Out:
# Timestamp('2023-08-21 13:00:00')

# %%
unique_assignment_types = df["Assignment Type"].unique()
print(unique_assignment_types)
# Out:
# ['Servicing' 'Intervention' 'Parts collection' 'Repairs' 'Training']

# %% [markdown]
# # Feature Engineering: Create New Features

# %%
# Example: Calculate the duration of each incident
# df_new = df['Incident Duration'] = df['End DateTime'] - df['Start DateTime']

# %%
# df_new

# %% [markdown]
# # Total Incidences from the Dataset

# %%
total_incidents = len(df['Incident Id'].unique())
print("Total number of incidents received:", total_incidents)
# Out:
# Total number of incidents received: 4244

# %%
total_incidents = df.shape[0]
print("Total number of incidents (including duplicates):", total_incidents)
# Out:
# Total number of incidents (including duplicates): 4342

# %%
df['Incident Id'].isna().sum()
# Out:
# 0

# %%
# Assuming your original DataFrame is 'df'
incident_id_df = df['Incident Id']
incident_id_df
# Out:
# 0       103360
# 1       103362
# 2       103324
# 3       103355
# 4       103374
#          ...
# 4337    120124
# 4338    120131
# 4339    120132
# 4340    120133
# 4341    120134
# Name: Incident Id, Length: 4342, dtype: int64

# %%
incident_counts = incident_id_df.value_counts()
total_incidents = len(incident_counts)

# Print the total number of unique incidents
print("Total number of unique incidents:", total_incidents)
# Out:
# Total number of unique incidents: 4244

# %%
# Assuming your original DataFrame is 'df'
duplicates = df[df.duplicated(subset='Incident Id', keep=False)]

# Get the count of duplicate Incident Ids
duplicate_count = len(duplicates)

# Print the count of duplicate Incident Ids
print("Total number of duplicate Incident Ids:", duplicate_count)
# Out:
# Total number of duplicate Incident Ids: 160

# %%
df.columns
# Out:
# Index(['Created By', 'Reported On', 'Created On', 'Travel Time', 'Incident Id',
#        'Customer', 'Location', 'Contract', 'Priority', 'SLA', 'Servicing Team',
#        'Category', 'Service Type', 'Subject', 'Technician', 'Item Id',
#        'Incident Summary', 'Resolution Summary', 'Task Summary', 'Model No',
#        'Serial No', 'Unit ID', 'Part Number', 'Service Report No', 'Task ID',
#        'Task Description', 'Task Type', 'Task Status', 'Hours to be Billed',
#        'Status', 'Contact Person', 'Geo', 'Assignment Type', 'Day of the Week',
#        'MONTH', 'YEAR', 'Time Taken', 'Start DateTime', 'End DateTime'],
#       dtype='object')

# %%
# Assuming your DataFrame is 'df'
# You can create a pivot table like this:
pivot_table = pd.pivot_table(df, 
                             values='Assignment Type',  # The column to summarize
                             index=df['MONTH'],  # Rows
                             columns=df['Assignment Type'],  # Columns
                             aggfunc='count',  # Aggregation function (count in this case)
                             fill_value=0)  # Fill NaN values with 0

# You can also add a 'Grand Total' row and column
pivot_table['Grand Total'] = pivot_table.sum(axis=1)
pivot_table.loc['Grand Total'] = pivot_table.sum()

# Print the pivot table
print(pivot_table)
# Out:
# Assignment Type  Intervention  Parts collection  Repairs  Servicing  Training  \
# MONTH
# Apr                       180                26        0        242         0
# Aug                       213                20       12        103        13
# Dec                        86                 3        0        125         0
# Feb                       172                23        0        174         0
# Jan                       214                31        0        151         0
# Jul                       160                13       36        186         4
# Jun                       201                20       33        219         4
# Mar                       186                43        0        349         0
# May                       274                28       38        124         0
# Nov                        91                10        0         62         0
# Oct                       122                 5        0         73         0
# ...

# %%
# Assuming your DataFrame is 'df'
# You can create a pivot table by 'Geo' column like this:
pivot_table = pd.pivot_table(df,
                             values='Assignment Type',  # The column to summarize
                             index=df['MONTH'],  # Rows (in this case, months)
                             columns=df['Geo'],  # Columns (in this case, Geo)
                             aggfunc='count',  # Aggregation function (count in this case)
                             fill_value=0)  # Fill NaN values with 0

# You can also add a 'Grand Total' row and column
pivot_table['Grand Total'] = pivot_table.sum(axis=1)
pivot_table.loc['Grand Total'] = pivot_table.sum()

# Print the pivot table
print(pivot_table)
# Out:
# Geo          Mauritius  Rodrigues  Seychelles  Grand Total
# MONTH
# Apr                363         85           0          448
# Aug                317         44           0          361
# Dec                186         28           0          214
# Feb                345         20           4          369
# Jan                331         52          13          396
# Jul                353         44           2          399
# Jun                440         37           0          477
# Mar                495         81           2          578
# May                412         51           1          464
# Nov                147         14           2          163
# Oct                180         13           7          200
# Sep                255         12           6          273
# Grand Total       3824        481          37         4342

# %%
import pandas as pd

# Assuming your DataFrame is 'df'
# You can create a pivot table by 'Geo' column like this:
pivot_table = pd.pivot_table(df,
                             values='Assignment Type',  # The column to summarize
                             index=df['MONTH'],  # Rows (in this case, months)
                             columns=df['Geo'],  # Columns (in this case, Geo)
                             aggfunc='count',  # Aggregation function (count in this case)
                             fill_value=0)  # Fill NaN values with 0

# Print the pivot table
print(pivot_table)

# Calculate Grand Total for each location
grand_total_mauritius = pivot_table['Mauritius'].sum().sum()
grand_total_rodrigues = pivot_table['Rodrigues'].sum().sum()
grand_total_seychelles = pivot_table['Seychelles'].sum().sum()

# Print the Grand Total for each location
print(f'Grand Total Mauritius: {grand_total_mauritius}')
print(f'Grand Total Rodrigues: {grand_total_rodrigues}')
print(f'Grand Total Seychelles: {grand_total_seychelles}')
# Out:
# Geo    Mauritius  Rodrigues  Seychelles
# MONTH
# Apr          363         85           0
# Aug          317         44           0
# Dec          186         28           0
# Feb          345         20           4
# Jan          331         52          13
# Jul          353         44           2
# Jun          440         37           0
# Mar          495         81           2
# May          412         51           1
# Nov          147         14           2
# Oct          180         13           7
# Sep          255         12           6
# Grand Total Mauritius: 3824
# Grand Total Rodrigues: 481
# Grand Total Seychelles: 37

# %%
df.columns
# Out:
# Index(['Created By', 'Reported On', 'Created On', 'Travel Time', 'Incident Id',
#        'Customer', 'Location', 'Contract', 'Priority', 'SLA', 'Servicing Team',
#        'Category', 'Service Type', 'Subject', 'Technician', 'Item Id',
#        'Incident Summary', 'Resolution Summary', 'Task Summary', 'Model No',
#        'Serial No', 'Unit ID', 'Part Number', 'Service Report No', 'Task ID',
#        'Task Description', 'Task Type', 'Task Status', 'Hours to be Billed',
#        'Status', 'Contact Person', 'Geo', 'Assignment Type', 'Day of the Week',
#        'MONTH', 'YEAR', 'Time Taken', 'Start DateTime', 'End DateTime'],
#       dtype='object')

# %%
# Create pivot tables for each Geo separately
pivot_table_mauritius = df[df['Geo'] == 'Mauritius'].pivot_table(
    values='Assignment Type', 
    index='MONTH', 
    aggfunc='count', 
    fill_value=0, 
    margins=True, 
    margins_name='Grand Total'
)

pivot_table_rodrigues = df[df['Geo'] == 'Rodrigues'].pivot_table(
    values='Assignment Type', 
    index='MONTH', 
    aggfunc='count', 
    fill_value=0, 
    margins=True, 
    margins_name='Grand Total'
)

pivot_table_seychelles = df[df['Geo'] == 'Seychelles'].pivot_table(
    values='Assignment Type', 
    index='MONTH', 
    aggfunc='count', 
    fill_value=0, 
    margins=True, 
    margins_name='Grand Total'
)

# Reset index for each pivot table
pivot_table_mauritius.reset_index(inplace=True)
pivot_table_rodrigues.reset_index(inplace=True)
pivot_table_seychelles.reset_index(inplace=True)

# Print pivot tables
print("Mauritius:")
print(pivot_table_mauritius)

print("\nRodrigues:")
print(pivot_table_rodrigues)

print("\nSeychelles:")
print(pivot_table_seychelles)
# Out:
# Mauritius:
#           MONTH  Assignment Type
# 0           Apr              363
# 1           Aug              317
# 2           Dec              186
# 3           Feb              345
# 4           Jan              331
# 5           Jul              353
# 6           Jun              440
# 7           Mar              495
# 8           May              412
# 9           Nov              147
# 10          Oct              180
# 11          Sep              255
# 12  Grand Total             3824
#
# Rodrigues:
#           MONTH  Assignment Type
# 0           Apr               85
# 1           Aug               44
# 2           Dec               28
# 3           Feb               20
# 4           Jan               52
# 5           Jul               44
# 6           Jun               37
# 7           Mar               81
# 8           May               51
# 9           Nov               14
# 10          Oct               13
# 11          Sep               12
# ...

# %%
import pandas as pd

# Assuming your dataset is named 'df'
# Get unique locations from the 'Location' column
unique_locations = df['Geo'].unique()

# Create a dictionary to store pivot tables for each location
pivot_tables = {}

# Iterate over unique locations and create pivot tables
for location in unique_locations:
    location_df = df[df['Geo'] == location]
    pivot_table = location_df.pivot_table(
        values='Day of the Week',  # Replace with the appropriate column name
        index='MONTH',
        columns='Assignment Type',
        aggfunc='count',
        fill_value=0,
        margins=True,
        margins_name='Grand Total'
    )
    pivot_table.reset_index(inplace=True)
    pivot_tables[location] = pivot_table

# Now, pivot_tables is a dictionary where keys are locations and values are pivot tables
# You can access pivot tables for specific locations like this:
# pivot_table_mauritius = pivot_tables['Mauritius']
# pivot_table_rodrigues = pivot_tables['Rodrigues']
# pivot_table_seychelles = pivot_tables['Seychelles']

# Print a specific location's pivot table
print("Mauritius:")
print(pivot_tables['Mauritius'])
# Out:
# Mauritius:
# Assignment Type        MONTH  Intervention  Parts collection  Repairs  \
# 0                        Apr           168                22        0
# 1                        Aug           208                19       12
# 2                        Dec            75                 3        0
# 3                        Feb           167                19        0
# 4                        Jan           184                21        0
# 5                        Jul           154                11       36
# 6                        Jun           186                 3       33
# 7                        Mar           171                35        0
# 8                        May           256                22       38
# 9                        Nov            83                 5        0
# 10                       Oct           109                 3        0
# 11                       Sep           132                 5        0
# ...

# %%
import pandas as pd

# Assuming your dataset is named 'df'
# Replace 'Intervention Time' with the correct column name
pivot_table = df.pivot_table(
    values='Day of the Week',
    index='MONTH',
    columns='Assignment Type',
    aggfunc='count',
    fill_value=0,
    margins=True,
    margins_name='Grand Total'
)

# Reorder columns to match the desired order
desired_order = ['Intervention',  'Parts collection',  'Repairs', 'Servicing',  'Training',  'Grand Total' ]
pivot_table = pivot_table[desired_order]

# Reset the index
pivot_table.reset_index(inplace=True)

# Print the pivot table
print(pivot_table)
# Out:
# Assignment Type        MONTH  Intervention  Parts collection  Repairs  \
# 0                        Apr           180                26        0
# 1                        Aug           213                20       12
# 2                        Dec            86                 3        0
# 3                        Feb           172                23        0
# 4                        Jan           214                31        0
# 5                        Jul           160                13       36
# 6                        Jun           201                20       33
# 7                        Mar           186                43        0
# 8                        May           274                28       38
# 9                        Nov            91                10        0
# 10                       Oct           122                 5        0
# 11                       Sep           145                 5        0
# ...

# %%
# Assuming your dataset is named 'df'
# Replace 'Intervention Type' with the correct column name
intervention_counts = df['Assignment Type'].value_counts()

# Create a bar chart
plt.figure(figsize=(10, 6), dpi=300)
intervention_counts.plot(kind='bar')
plt.title('Count of Assignment Type')
plt.xlabel('Assignment Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  # Import seaborn for color palettes

# Assuming your dataset is named 'df'
# Replace 'Intervention Type' with the correct column name
intervention_counts = df['Assignment Type'].value_counts()

# Choose a color palette from seaborn
# You can explore different palettes at https://seaborn.pydata.org/tutorial/color_palettes.html
color_palette = sns.color_palette("husl", len(intervention_counts))

# Create a bar chart with custom colors
plt.figure(figsize=(10, 6), dpi=300)
intervention_counts.plot(kind='bar', color=color_palette)
plt.title('Count of Assignment Type')
plt.xlabel('Assignment Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the chart
plt.show()

# %%
# Assuming your dataset is named 'df'
# Replace 'Intervention Type' and 'Created On' with the correct column names
df['Month'] = pd.to_datetime(df['Created On']).dt.strftime('%b')

# Define the custom order of months
custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Pivot the data
pivot_df = df.pivot_table(index='Assignment Type', columns='Month', values='Incident Id', aggfunc='count', fill_value=0)
pivot_df = pivot_df.reindex(columns=custom_month_order)

# Choose a color palette from seaborn
color_palette = sns.color_palette("husl", len(pivot_df.columns))

# Create a grouped bar chart with custom colors
plt.figure(figsize=(20, 10), dpi=300)
pivot_df.plot(kind='bar', color=color_palette, width=0.8)
plt.title('Count of Assignment Type by Month')
plt.xlabel('Assignment Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Month', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# Show the chart
plt.show()

# %%
# Assuming your dataset is named 'df'
# Replace 'Intervention Type' and 'Created On' with the correct column names
df['Month'] = pd.to_datetime(df['Created On']).dt.strftime('%b')

# Define the custom order of months
custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Pivot the data
pivot_df = df.pivot_table(index='Month', columns='Assignment Type', values='Incident Id', aggfunc='count', fill_value=0)
pivot_df = pivot_df.reindex(index=custom_month_order)

# Choose a color palette from seaborn
color_palette = sns.color_palette("husl", len(pivot_df.columns))

# Create a grouped bar chart with custom colors
plt.figure(figsize=(20, 10), dpi=300)
ax = pivot_df.plot(kind='bar', color=color_palette, width=0.8)
plt.title('Count of Assignment Types by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')

# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# # Count of Mauritius Intervention Types by Month

# %%
# Define the custom order of months
custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Convert 'Created On' to a datetime column (if it's not already)
df['Created On'] = pd.to_datetime(df['Created On'])

# Extract month from 'Created On'
df['Month'] = df['Created On'].dt.strftime('%b')

# Filter the DataFrame to include only the relevant data (e.g., Geo == 'Mauritius')
filtered_df = df[df['Geo'] == 'Mauritius']

# Create a bar chart
plt.figure(figsize=(10, 6), dpi=300)
sns.countplot(data=filtered_df, x='Month', order=custom_month_order, hue='Assignment Type', palette='Set1')
plt.title('Count of Mauritius Assignment Types by Month')
plt.xlabel('Month')
plt.ylabel('Count')

# Display the legend outside the plot
plt.legend(title='Assignment Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Count of Rodrigues Intervention Types by Month

# %%
# Define the custom order of months
custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Convert 'Created On' to a datetime column (if it's not already)
df['Created On'] = pd.to_datetime(df['Created On'])

# Extract month from 'Created On'
df['Month'] = df['Created On'].dt.strftime('%b')

# Filter the DataFrame to include only the relevant data (e.g., Geo == 'Rodrigues')
filtered_df = df[df['Geo'] == 'Rodrigues']

# Create a bar chart
plt.figure(figsize=(10, 6), dpi=300)
sns.countplot(data=filtered_df, x='Month', order=custom_month_order, hue='Assignment Type', palette='Set1')
plt.title('Count of Rodrigues Assignment Types by Month')
plt.xlabel('Month')
plt.ylabel('Count')

# Display the legend outside the plot
plt.legend(title='Intervention Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Count of Seychelles Intervention Types by Month

# %%
# Define the custom order of months
custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Convert 'Created On' to a datetime column (if it's not already)
df['Created On'] = pd.to_datetime(df['Created On'])

# Extract month from 'Created On'
df['Month'] = df['Created On'].dt.strftime('%b')

# Filter the DataFrame to include only the relevant data (e.g., Geo == 'Seychelles')
filtered_df = df[df['Geo'] == 'Seychelles']

# Create a bar chart
plt.figure(figsize=(10, 6))
sns.countplot(data=filtered_df, x='Month', order=custom_month_order, hue='Assignment Type', palette='Set1')
plt.title('Count of Seychelles Assignment Types by Month')
plt.xlabel('Month')
plt.ylabel('Count')

# Display the legend outside the plot
plt.legend(title='Assignment Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Define the custom order of months
custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Convert 'Created On' to a datetime column (if it's not already)
# df['Created On'] = pd.to_datetime(df['Created On'])

# Extract month from 'Created On'
df['Month'] = df['Created On'].dt.strftime('%b')

# Create a bar chart
plt.figure(figsize=(10, 6), dpi=300)
sns.countplot(data=df, x='Month', order=custom_month_order, hue='Assignment Type', palette='Set1')
plt.title('Count of Assignment Types by Month (All Geo)')
plt.xlabel('Month')
plt.ylabel('Count')

# Display the legend outside the plot
plt.legend(title='Assignment Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Total No. of servicing per technician monthly/yearly

# %%
# Assuming your dataset is named 'df'
# Replace column names as needed
df['Created On'] = pd.to_datetime(df['Created On'])
custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df['Month'] = pd.Categorical(df['Created On'].dt.strftime('%b'), categories=custom_month_order, ordered=True)

# Pivot the data to get counts per technician and month
pivot_df = df.pivot_table(index=['Technician', 'Assignment Type'], columns='Month', values='Created On', aggfunc='count', fill_value=0, margins=True, margins_name='Grand Total')

# Calculate the total per technician
pivot_df['Total'] = pivot_df.sum(axis=1)

# Sort the table by the Grand Total in descending order
pivot_df = pivot_df.sort_values(by='Grand Total', ascending=False)

# Display the table
print(pivot_df)
# Out:
# Month                          Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  \
# Technician   Assignment Type
# Grand Total                    396  369  578  448  464  477  399  361  273
# Jose         Servicing          58   71   96   31   41   37   30   31   44
# Jean Bernard Servicing          30   41   91   51   14   83   42   16   43
# michel       Intervention       47   38   53   44   46   56   38   47   26
# Daniel       Intervention       37   42   38   33   65   40   31   52   26
# ...                            ...  ...  ...  ...  ...  ...  ...  ...  ...
# Yoven        Parts collection    0    0    0    0    0    0    0    0    0
#              Repairs             0    0    0    0    0    0    0    0    0
#              Servicing           0    0    0    0    0    0    0    0    0
#              Training            0    0    0    0    0    0    0    0    0
# Zaid         Training            0    0    0    0    0    0    0    0    0
#
# ...

# %% [markdown]
# # Total No. of Interventions per technician monthly/yearly

# %%
import pandas as pd

# Assuming 'df' is your DataFrame

# Create a new column 'Intervention' based on 'Task Type' and 'Task Status'
df['Intervention'] = df['Task Type'] + ' - ' + df['Task Status']

# Create a pivot table
pivot_df = df.pivot_table(index=['Technician', 'Assignment Type'], 
                          columns=['YEAR', 'MONTH'], 
                          values='Intervention', 
                          aggfunc='count', 
                          fill_value=0)

# Adding Total columns for each year and grand total
pivot_df['Total'] = pivot_df.sum(axis=1)
pivot_df.loc['Total'] = pivot_df.sum()

# Displaying the result
print(pivot_df)
# Out:
# YEAR                             2022                                          \
# MONTH                             Apr  Aug  Dec  Feb  Jan  Jul  Jun  Mar  May
# (Alvin, Intervention)               0    0    0    0    0    0    0    0    0
# (Alvin, Servicing)                  0    0    0    0    4    0    0    0    0
# (Antoine, Intervention)             0    0    0    0    0    2    0    0    1
# (Antoine, Servicing)                0    0    0    0    4    0    0    0    0
# (Burty, Intervention)              18    0    0   21   17    0   26   16   21
# (Burty, Parts collection)           2    0    0    2    0    0    1    1    0
# (Burty, Servicing)                  4    0    0    0    3    0    0   27    0
# (Chrisler, Intervention)            0    0    0    0    0    0    0    0    0
# (Chrisler, Parts collection)        0    0    0    0    0    0    0    0    0
# (Chrisler, Repairs)                 0    0    0    0    0    0    0    0    0
# ...

# %% [markdown]
# # Total Region-wise Interventions per Customer

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Print column names to identify the correct column for intervention count
print(df.columns)

# Replace 'Intervention' with the actual column name representing the count of interventions
pivot_df = df.pivot_table(index=['Geo', 'Location', 'Customer'], 
                          columns=['YEAR', 'MONTH'], 
                          values='Intervention',  # Replace 'YourActualColumnName' with the correct column name
                          aggfunc='count', 
                          fill_value=0)

# Adding Total columns for each year and grand total
pivot_df['Total'] = pivot_df.sum(axis=1)
pivot_df.loc['Total'] = pivot_df.sum()

# Displaying the result
print(pivot_df)
# Out:
# Index(['Created By', 'Reported On', 'Created On', 'Travel Time', 'Incident Id',
#        'Customer', 'Location', 'Contract', 'Priority', 'SLA', 'Servicing Team',
#        'Category', 'Service Type', 'Subject', 'Technician', 'Item Id',
#        'Incident Summary', 'Resolution Summary', 'Task Summary', 'Model No',
#        'Serial No', 'Unit ID', 'Part Number', 'Service Report No', 'Task ID',
#        'Task Description', 'Task Type', 'Task Status', 'Hours to be Billed',
#        'Status', 'Contact Person', 'Geo', 'Assignment Type', 'Day of the Week',
#        'MONTH', 'YEAR', 'Time Taken', 'Start DateTime', 'End DateTime',
#        'Month', 'Intervention'],
#       dtype='object')
# YEAR                                               2022                      \
# MONTH                                               Apr  Aug  Dec  Feb  Jan
# (Mauritius, 4TH FLOOR / H/O, Bank)                    0    0    0    0    0
# ...

# %% [markdown]
# # Total No. of Interventions per Weekday/Customer/Technician [ ]

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Create a pivot table
pivot_df = df.pivot_table(index=['Assignment Type', 'Day of the Week', 'Customer', 'Technician'], 
                          columns=['YEAR'], 
                          values='Intervention', 
                          aggfunc='count', 
                          fill_value=0)

# Adding Total columns for each year and grand total
pivot_df['Total'] = pivot_df.sum(axis=1)
pivot_df.loc['Total'] = pivot_df.sum()

# Displaying the result
print(pivot_df)
# Out:
# YEAR                                          2022  2023  Total
# (Intervention, Fri, Bank, Alvin)                 1     0      1
# (Intervention, Fri, Bank, Antoine)               2     0      2
# (Intervention, Fri, Bank, Burty)                 5     0      5
# (Intervention, Fri, Bank, Daniel)                7     2      9
# (Intervention, Fri, Bank, Gaspard)               3     0      3
# ...                                            ...   ...    ...
# (Training, Sat, Birger Office, Jean Bernard)     0     1      1
# (Training, Sat, College, Daniel)                 0     1      1
# (Training, Thu, Tourism Authority, michel)       0     1      1
# (Training, Tue, Birger Office, michel)           0     1      1
# Total                                         2608  1734   4342
#
# [531 rows x 3 columns]

# %% [markdown]
# # Technician == Jose

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Filter data for the specific technician (e.g., Jose)
df_jose = df[df['Technician'] == 'Jose']

# Create a pivot table
pivot_df = df_jose.pivot_table(index=['Assignment Type', 'Day of the Week', 'Customer'], 
                               columns=['YEAR'], 
                               values='Incident Id',  # Replace with the actual column name
                               aggfunc='count', 
                               fill_value=0)

# Adding Total columns for each year and grand total
pivot_df['Total'] = pivot_df.sum(axis=1)
pivot_df.loc['Grand Total'] = pivot_df.sum()

# Displaying the result
print(pivot_df)
# Out:
# YEAR                                    2022  2023  Total
# (Intervention, Fri, Bank)                 14     3     17
# (Intervention, Fri, Birger Office)         3     2      5
# (Intervention, Fri, Business)             18     0     18
# (Intervention, Fri, College)               8     5     13
# (Intervention, Mon, Bank)                  9     1     10
# (Intervention, Mon, Birger Office)         3     1      4
# (Intervention, Mon, Business)             13     1     14
# (Intervention, Mon, College)               9     1     10
# (Intervention, Sat, Bank)                  1     0      1
# (Intervention, Sat, Birger Office)         1     1      2
# (Intervention, Sat, Business)              6     0      6
# (Intervention, Sat, College)               6     0      6
# (Intervention, Sun, Bank)                  0     1      1
# (Intervention, Thu, Bank)                  8     0      8
# (Intervention, Thu, Birger Office)         3     0      3
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Extract the year from the 'Created On' column
df['YEAR'] = pd.to_datetime(df['Created On']).dt.year

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Assignment Type', hue='YEAR', palette='husl')

# Add labels and title
plt.xlabel('Assignment Type')
plt.ylabel('Count')
plt.title('Count of Assignment Type with Distinction Between Years')

# Show the plot
plt.legend(title='Year')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bar chart where Technician == Jose

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Filter data for the specific technician (e.g., Jose)
df_jose = df[df['Technician'] == 'Jose']

# Extract the year from the 'Created On' column
df_jose['YEAR'] = pd.to_datetime(df_jose['Created On']).dt.year

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.countplot(data=df_jose, x='Assignment Type', hue='YEAR', palette='husl')

# Add labels and title
plt.xlabel('Assignment Type')
plt.ylabel('Count')
plt.title('Count of Assignment Type for Jose with Distinction Between Years')

# Show the plot
plt.legend(title='Year')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Filter data for the specific technician (e.g., Jose)
df_jose = df[df['Technician'] == 'Gaspard']

# Extract the year from the 'Created On' column
df_jose['YEAR'] = pd.to_datetime(df_jose['Created On']).dt.year

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.countplot(data=df_jose, x='Assignment Type', hue='YEAR', palette='husl')

# Add labels and title
plt.xlabel('Assignment Type')
plt.ylabel('Count')
plt.title('Count of Assignment Type for Gaspard with Distinction Between Years')

# Show the plot
plt.legend(title='Year')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Count of Assignment Type in General

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Replace 'YourActualColumnName' with the correct column name representing the count of interventions
# Replace 'YourDataPath' with the actual path to your dataset
# df = pd.read_csv('YourDataPath')

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Assignment Type', hue='YEAR', palette='husl')

# Add labels and title
plt.xlabel('Assignment Type')
plt.ylabel('Count')
plt.title('Count of Assignment Type')

# Show the plot
plt.legend(title='Year')
plt.show()

# %% [markdown]
# # Intervention by Customer

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is already named 'df'

# Convert 'YEAR' and 'MONTH' columns to strings
df['YEAR'] = df['YEAR'].astype(str)
df['MONTH'] = df['MONTH'].astype(str)

# Create a pivot table to count the occurrences of Assignment Type for each Customer
pivot_table = df.pivot_table(index=['Customer'], columns=['Assignment Type'], values='Incident Id', aggfunc='count', fill_value=0)

# Add a column for Grand Total
pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# Plot the bar chart
pivot_table.plot(kind='bar', stacked=True, figsize=(20, 10), colormap='viridis')

# Add labels and title
plt.xlabel('Customer')
plt.ylabel('Count')
plt.title('Intervention by Customer and Assignment Type')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is already named 'df'

# Convert 'YEAR' and 'MONTH' columns to strings
df['YEAR'] = df['YEAR'].astype(str)
df['MONTH'] = df['MONTH'].astype(str)

# Create a pivot table to count the occurrences of Assignment Type for each Customer
pivot_table = df.pivot_table(index=['Customer'], columns=['Assignment Type'], values='Incident Id', aggfunc='count', fill_value=0)

# Add a column for Grand Total
pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# Plot the bar chart with adjusted bar width
pivot_table.plot(kind='bar', stacked=True, figsize=(20, 10), colormap='viridis', width=0.8)  # You can adjust the width value

# Add labels and title
plt.xlabel('Customer')
plt.ylabel('Count')
plt.title('Intervention by Customer and Assignment Type')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is already named 'df'

# Convert 'YEAR' and 'MONTH' columns to strings
df['YEAR'] = df['YEAR'].astype(str)
df['MONTH'] = df['MONTH'].astype(str)

# Create a pivot table to count the occurrences of Assignment Type for each Customer
pivot_table = df.pivot_table(index=['Customer'], columns=['Assignment Type'], values='Incident Id', aggfunc='count', fill_value=0)

# Add a column for Grand Total
pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# Get the number of unique Assignment Types
num_assignment_types = len(pivot_table.columns) - 1

# Calculate bar width and position
bar_width = 0.2  # Adjust the bar width as needed
bar_position = [(i * bar_width) for i in range(num_assignment_types)]

# Convert bar_position to a list of strings
bar_position_str = [str(pos) for pos in bar_position]

# Plot the bar chart with adjusted bar width and position
for i, assignment_type in enumerate(pivot_table.columns[:-1]):
    plt.bar(pivot_table.index + bar_position_str[i], pivot_table[assignment_type], width=bar_width, label=assignment_type)

# Add labels and title
plt.xlabel('Customer')
plt.ylabel('Count')
plt.title('Intervention by Customer and Assignment Type')
plt.xticks(rotation=90)  # Rotate x-axis labels to 90 degrees
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is already named 'df'

# Convert 'YEAR' and 'MONTH' columns to strings
df['YEAR'] = df['YEAR'].astype(str)
df['MONTH'] = df['MONTH'].astype(str)

# Create a pivot table to count the occurrences of Assignment Type for each Customer
pivot_table = df.pivot_table(index=['Customer'], columns=['Assignment Type'], values='Incident Id', aggfunc='count', fill_value=0)

# Add a column for Grand Total
pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# Get the number of unique Assignment Types
num_assignment_types = len(pivot_table.columns) - 1

# Calculate bar width and position
bar_width = 0.2  # Adjust the bar width as needed
bar_position = [(i * bar_width) for i in range(num_assignment_types)]

# Convert bar_position to a list of strings
bar_position_str = [str(pos) for pos in bar_position]

# Increase figure size
plt.figure(figsize=(15, 8))

# Plot the bar chart with adjusted bar width and position
for i, assignment_type in enumerate(pivot_table.columns[:-1]):
    plt.bar(pivot_table.index + bar_position_str[i], pivot_table[assignment_type], width=bar_width, label=assignment_type)

# Add labels and title
plt.xlabel('Customer')
plt.ylabel('Count')
plt.title('Intervention by Customer and Assignment Type')
plt.xticks(rotation=90)  # Rotate x-axis labels to 90 degrees
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is already named 'df'

# Convert 'YEAR' and 'MONTH' columns to strings
df['YEAR'] = df['YEAR'].astype(str)
df['MONTH'] = df['MONTH'].astype(str)

# Ensure 'Customer' column is of type string
df['Customer'] = df['Customer'].astype(str)

# Create a pivot table to count the occurrences of Assignment Type for each Customer
pivot_table = df.pivot_table(index=['Customer'], columns=['Assignment Type'], values='Incident Id', aggfunc='count', fill_value=0)

# Add a column for Grand Total
pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# Get the number of unique Assignment Types
num_assignment_types = len(pivot_table.columns) - 1

# Calculate bar width and position
bar_width = 0.2  # Adjust the bar width as needed
bar_position = [(i * bar_width) for i in range(num_assignment_types)]

# Convert bar_position to a list of strings
bar_position_str = [str(pos) for pos in bar_position]

# Increase figure size
plt.figure(figsize=(15, 8))

# Plot the bar chart with adjusted bar width and position
for i, assignment_type in enumerate(pivot_table.columns[:-1]):
    plt.bar(pivot_table.index + bar_position_str[i], pivot_table[assignment_type], width=bar_width, label=assignment_type)

# Add labels and title
plt.xlabel('Customer')
plt.ylabel('Count')
plt.title('Intervention by Customer and Assignment Type')
plt.xticks(rotation=90)  # Rotate x-axis labels to 90 degrees
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataset is named 'df'
# Replace column names as needed
top_10_locations = df['Location'].value_counts().nlargest(10).index
top_10_df = df[df['Location'].isin(top_10_locations)]

# Create a horizontal bar plot
plt.figure(figsize=(10, 6))
sns.countplot(data=top_10_df, y='Location', hue='Assignment Type', dodge=False, palette='Set1')
plt.title('Top 10 Interventions by Location')
plt.xlabel('Count')
plt.ylabel('Location - Customer')
plt.legend(title='Assignment Type')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataset is named 'df'
# Replace column names as needed
top_10_locations = df['Location'].value_counts().nlargest(10).index
top_10_df = df[df['Location'].isin(top_10_locations)]

# Group data by location and customer and count interventions
grouped = top_10_df.groupby(['Location', 'Customer'])['Assignment Type'].count().unstack(fill_value=0)

# Print the table-like structure
print("Location\tCustomer\tBars")
for location in grouped.index:
    for customer in grouped.columns:
        count = grouped.loc[location, customer]
        if count > 0:
            print(f"{location}\t{customer}\t{count}")
# Out:
# Location	Customer	Bars
# CUREPIPE	Administrators	2
# CUREPIPE	Bank	28
# CUREPIPE	Birger Office	39
# CUREPIPE	Business	19
# CUREPIPE	College	7
# CUREPIPE	Mauritius Network Services Ltd	1
# CUREPIPE	Mauritius Revenue Authority	1
# Curepipe	Bank	38
# Curepipe	Birger Office	2
# Curepipe	Business	45
# Curepipe	College	58
# EBENE	Bank	39
# EBENE	Birger Office	31
# EBENE	Business	48
# EBENE	College	1
# Ebene	Bank	135
# Ebene	Birger Office	3
# Ebene	Business	70
# GRAND BAY	Administrators	2
# GRAND BAY	Bank	21
# GRAND BAY	Birger Office	22
# GRAND BAY	Business	35
# GRAND BAY	College	4
# GRAND BAY	Ministry of Tourism	1
# PORT LOUIS	Bank	39
# PORT LOUIS	Birger Office	57
# PORT LOUIS	Business	81
# PORT LOUIS	College	17
# PORT LOUIS	Mauritius Network Services Ltd	4
# PORT LOUIS	Ministry of Tourism	2
# PORT LOUIS	Tourism Authority	2
# Port-Louis	Bank	94
# Port-Louis	Birger Office	81
# Port-Louis	Business	236
# Port-Louis	College	37
# Port-Louis	Department of Civil Aviation	1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataset is named 'df'
# Replace column names as needed
top_10_locations = df['Location'].value_counts().nlargest(10).index
top_10_df = df[df['Location'].isin(top_10_locations)]

# Group data by location and customer and count interventions
grouped = top_10_df.groupby(['Location', 'Customer'])['Assignment Type'].count().unstack(fill_value=0).reset_index()

# Create a horizontal bar plot with customers on the left
plt.figure(figsize=(10, 6))
customers = grouped.columns[1:]  # Exclude the 'Location' column
location_labels = grouped['Location']

for customer in customers:
    plt.barh(location_labels, grouped[customer], label=customer)

plt.title('Top 10 Interventions by Location')
plt.xlabel('Count (Bars)')
plt.ylabel('Location')

# Show the legend
plt.legend(title='Customer', loc='lower right', bbox_to_anchor=(1.05, 1))

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataset is named 'df'
# Replace column names as needed
location = 'Curepipe'  # Change this to the location you want to start with
top_location_df = df[df['Location'] == location]

# Get the top 10 customers for the specified location
top_10_customers = top_location_df['Customer'].value_counts().nlargest(10).index

# Filter the DataFrame to include only the top 10 customers
top_10_df = top_location_df[top_location_df['Customer'].isin(top_10_customers)]

# Create a horizontal bar plot
plt.figure(figsize=(10, 6), dpi=300)
sns.barplot(data=top_10_df, y=top_10_df['Customer'], x=top_10_df.index, hue='Assignment Type', dodge=False, palette='Set1')
plt.title(f'Top 10 Interventions for {location}')
plt.xlabel('Count (Bars)')
plt.ylabel('Customer')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Assuming your dataset is named 'df'
# Replace column names as needed
location = 'Curepipe'  # Change this to the location you want to start with
top_location_df = df[df['Location'] == location]

# Get the top 10 customers for the specified location
top_10_customers = top_location_df['Customer'].value_counts().nlargest(10).index

# Filter the DataFrame to include only the top 10 customers
top_10_df = top_location_df[top_location_df['Customer'].isin(top_10_customers)]

# Create a horizontal clustered bar plot
plt.figure(figsize=(10, 6), dpi=300)
sns.barplot(data=top_10_df, y=top_10_df['Customer'], x=top_10_df.index, hue='Assignment Type', dodge=True, palette='Set1')

plt.title(f'Top 10 Interventions for {location}')
plt.xlabel('Count (Bars)')
plt.ylabel('Customer')

# Add space between legend and plot
plt.legend(title='Assignment Type', bbox_to_anchor=(1.2, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Assuming your dataset is named 'df'
# Replace column names as needed
location = 'Curepipe'  # Change this to the location you want to start with
top_location_df = df[df['Location'] == location]

# Get the top 10 customers for the specified location
top_10_customers = top_location_df['Customer'].value_counts().nlargest(10).index

# Filter the DataFrame to include only the top 10 customers
top_10_df = top_location_df[top_location_df['Customer'].isin(top_10_customers)]

# Create a horizontal clustered bar plot
plt.figure(figsize=(10, 6), dpi=300)
sns.barplot(data=top_10_df, y=top_10_df['Customer'], x=top_10_df.index, hue='Assignment Type', dodge=True, palette='Set1')

plt.title(f'Top 10 Interventions for {location}')
plt.xlabel('Count (Bars)')
plt.ylabel('Customer')

# Remove gridlines
sns.despine()

# Add space between legend and plot
plt.legend(title='Assignment Type', bbox_to_anchor=(1.2, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# # Assuming your dataset is named 'df'
# # Replace column names as needed
# columns_to_select = ['Created On', 'Customer', 'Location', 'Serial No', 'Zone-wise', 'No. of Years', 'Assignment Type']
# selected_df = df[columns_to_select]

# # Group and count interventions by Customer, Zone wise, and Month
# intervention_counts = selected_df.groupby(['Customer', 'Zone-wise', 'No. of Years', 'Assignment Type'])['Created On'].count().reset_index()

# # Pivot the data to create the table
# pivot_table = intervention_counts.pivot_table(
#     values='Created On',
#     index=['Customer', 'Zone-wise', 'No. of Years'],
#     columns='Assignment Type',
#     aggfunc='sum',
#     fill_value=0
# )

# # Add a 'Grand Total' column
# # Calculate the 'Grand Total' column
# pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# # Reorder the columns based on the specified order (e.g., Jan, Feb, Mar, ...)
# # Define the custom order of months
# custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Grand Total']

# # Pivot the data to create the table
# pivot_table = intervention_counts.pivot_table(
#     values='Created On',
#     index=['Customer', 'Zone-wise', 'No. of Years'],
#     columns='Assignment Type',
#     aggfunc='sum',
#     fill_value=0
# )

# # Add a 'Grand Total' column
# pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# # Reorder the columns based on the custom_month_order
# pivot_table = pivot_table.reindex(columns=custom_month_order)

# # Display the pivot table
# print(pivot_table)

# %%
# Check the current column names in the pivot table
print(pivot_table.columns)
# Out:
# Index(['Intervention', 'Parts collection', 'Repairs', 'Servicing', 'Training',
#        'Grand Total'],
#       dtype='object', name='Assignment Type')

# %% [markdown]
# # Top 10 Interventions by Location

# %%
# Group the data by 'Geo' and count the number of incidents
geo_counts = df['Geo'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(geo_counts, labels=geo_counts.index, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))

# Add a circle at the center (optional for an empty center)
circle = plt.Circle((0, 0), 0.3, color='white')
plt.gca().add_artist(circle)

# Add a title
plt.title('Incidents by Geo')

# Display the pie chart
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# # Top 10 Incidents by FE

# %%
# Group the data by 'Subject' and count the number of incidents
subject_counts = df['Subject'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(subject_counts, labels=subject_counts.index, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))

# Add a circle at the center (optional for an empty center)
circle = plt.Circle((0, 0), 0.3, color='white')
plt.gca().add_artist(circle)

# Add a title
plt.title('Incidents by Subject')

# Display the pie chart
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'Subject' and count the number of incidents
subject_counts = df['Subject'].value_counts()

# Generate explosion values for each slice (adjust the values as needed)
explode = [0.1] * len(subject_counts)

# Create a pie chart
plt.figure(figsize=(8, 8), dpi=300)
plt.pie(subject_counts, labels=subject_counts.index, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4), explode=explode)

# Add a circle at the center (optional for an empty center)
circle = plt.Circle((0, 0), 0.3, color='white')
plt.gca().add_artist(circle)

# Add a title
plt.title('Incidents by Subject')

# Display the pie chart
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Count incidents based on the 'Subject' column
subject_counts = df['Subject'].value_counts()

# Display the counts
print(subject_counts)
# Out:
# PM                                1671
# Repairs                           1473
# Replace parts                      306
# Office work                        285
# Deliver & Collect                  152
# Survey                             104
# Software Failure                    89
# Hardware Failure                    68
# Collect parts                       36
# Paper jam                           27
# Configuration                       22
# Training                            21
# Replace Toner                       15
# Jamming                             13
# Network port not Active              8
# Power supply failed                  8
# Office Work                          8
# Unable to connect (print/scan)       7
# Paper jump                           7
# Installation                         5
# keypad                               3
# Memory issue                         2
# Counter Display                      2
# Embosser                             2
# ...

# %% [markdown]
# # Total No. of Interventions per Weekday/Bank/Technician

# %%
# Assuming your dataset is named 'df'
# Replace column names as needed
columns_to_select = ['Start DateTime', 'Customer', 'Location', 'Subject', 'Technician', 'Assignment Type', 'Day of the Week']
selected_df = df[columns_to_select]


# Create a pivot table to count interventions by weekday, customer, location, subject, technician, and intervention type
pivot_table = selected_df.pivot_table(index=['Day of the Week', 'Customer', 'Location', 'Subject', 'Technician', 'Assignment Type'], 
                                      columns='Start DateTime', aggfunc='size', fill_value=0)

# Display the pivot table
print(pivot_table)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Print the column names of your DataFrame
print(df.columns)
# Out:
# Index(['Created By', 'Reported On', 'Created On', 'Travel Time', 'Incident Id',
#        'Customer', 'Location', 'Contract', 'Priority', 'SLA', 'Servicing Team',
#        'Category', 'Service Type', 'Subject', 'Technician', 'Item Id',
#        'Incident Summary', 'Resolution Summary', 'Task Summary', 'Model No',
#        'Serial No', 'Unit ID', 'Part Number', 'Service Report No', 'Task ID',
#        'Task Description', 'Task Type', 'Task Status', 'Hours to be Billed',
#        'Status', 'Contact Person', 'Geo', 'Assignment Type', 'Day of the Week',
#        'MONTH', 'YEAR', 'Time Taken', 'Start DateTime', 'End DateTime',
#        'Month', 'Intervention'],
#       dtype='object')

# %%
# %config NotebookApp.iopub_data_rate_limit=10000000

# %%
from tabulate import tabulate  # Import the tabulate function

# Assuming your dataset is named 'df'
# Replace column names as needed
columns_to_select = ['Start DateTime', 'Customer', 'Location', 'Subject', 'Technician', 'Assignment Type', 'Day of the Week']
selected_df = df[columns_to_select]

# Create a pivot table to count interventions by weekday, customer, location, subject, technician, and intervention type
pivot_table = selected_df.pivot_table(index=['Day of the Week', 'Customer', 'Location', 'Subject', 'Technician', 'Assignment Type'], 
                                      columns='Start DateTime', aggfunc='size', fill_value=0)

# Convert the pivot table to a DataFrame
pivot_df = pd.DataFrame(pivot_table)

# Add a border around the DataFrame
bordered_table = tabulate(pivot_df, headers='keys', tablefmt='pretty', showindex=True)

# Display the bordered table
print(bordered_table)

# %% [markdown]
# # Status of Incidents per Technician

# %%
import pandas as pd

# Assuming your dataset is named 'df'
# Replace column names as needed
columns_to_select = ['Created On', 'Technician', 'Status']
selected_df = df[columns_to_select]

# Extract the month from the 'Created On' column
selected_df['Month'] = selected_df['Created On'].dt.strftime('%b')

# Pivot the DataFrame to get the counts of each status per technician and month
pivot_table = selected_df.pivot_table(index=['Technician', 'Status'], columns='Month', aggfunc='size', fill_value=0)

# Calculate the 'Grand Total' by summing the counts across all months
pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# Reorder the columns to match the desired format
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Grand Total']
pivot_table = pivot_table[month_order]

# Display the pivot table
print(pivot_table)
# Out:
# Month                             Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  \
# Technician   Status
# Alvin        Assigned               4    1    0    0    0    0    0    0
#              Closed                 0    0    0    0    0    0    0    0
# Antoine      Assigned               4    0    1    0    0    0    0    0
#              Closed                 5    3    1    0    1    0    2    0
# Burty        Assigned               0    1    1    0    2    0    0    0
#              Closed                20   22   43   24   19   27    0    0
# Chrisler     Assigned               0    0    0    9   30   10   12   19
# Daniel       Assigned              49   37   14   72   84   65   79   62
#              Closed                 9   38   80    7    6   32    3    3
# Francois     Assigned               0    0    0    0    8    0    0    0
#              Closed                 8    5    6    8   14    3    2    1
# Gaspard      Assigned               0    0    0    0    1    0    5    0
# ...

# %% [markdown]
# # Out of Zone Interaction/Technician

# %%
import pandas as pd

# Load your dataset or replace it with your data
# df = pd.read_csv('your_data.csv')

# Filter the dataset for 'ATM Interventions' and 'Technician 4'
# 'Intervention',  'Parts collection',  'Repairs', 'Servicing',  'Training'
filtered_df = df[(df['Assignment Type'] == 'Intervention') | (df['Technician'] == 'Jose')]

# Extract the month from the 'Created On' column
filtered_df['Month'] = pd.to_datetime(filtered_df['Created On']).dt.strftime('%b')

# Pivot the DataFrame to get the counts of interventions per technician and month
pivot_table = filtered_df.pivot_table(index='Technician', columns='Month', aggfunc='size', fill_value=0)

# Calculate the grand total by summing all the values in the pivot_table
grand_total = pivot_table.values.sum()

# Reorder the columns to match the desired format
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug']
pivot_table = pivot_table[month_order]

# Display the pivot_table
print(pivot_table)

# Display the grand total
print(f'Grand Total: {grand_total}')
# Out:
# Month         Jan  Feb  Mar  Apr  May  Jun  Jul  Aug
# Technician
# Alvin           0    0    0    0    0    0    0    0
# Antoine         3    1    1    0    1    0    2    0
# Burty          17   21   16   18   21   26    0    0
# Chrisler        0    0    0    4   13    4    2    4
# Daniel         37   42   38   33   65   40   31   52
# Francois        7    5    3    8   22    3    2    1
# Gaspard        14    2    4    8   10    8    1    0
# Ghislain        0    0    4    6   12    3    8   20
# Jean Bernard   32   25   24   26   37   27   31   39
# Jean Jacques    1    0    0    0    0    0    0    0
# Jean Paul      13    2   10    4    7    7    3    5
# Joevani        11    1    0    0    1    0    5    0
# Jose           85  104  131   51   67   55   59   61
# Yoven           0    0    0    0    0    1    0    0
# Zaid            9    7    3   11   14    8    9   20
# michel         47   38   53   44   46   56   38   47
# Grand Total: 2620

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# Load your dataset or replace it with your data
# df = pd.read_csv('your_data.csv')

# Filter the dataset for 'ATM Interventions' and 'Technician 4'
filtered_df = df[(df['Assignment Type'] == 'Intervention') | (df['Technician'] == 'Jose')]

# Extract the month from the 'Created On' column
filtered_df['Month'] = pd.to_datetime(filtered_df['Created On']).dt.strftime('%b')

# Pivot the DataFrame to get the counts of interventions per technician and month
pivot_table = filtered_df.pivot_table(index='Technician', columns='Month', aggfunc='size', fill_value=0)

# Calculate the grand total by summing all the values in the pivot_table
grand_total = pivot_table.values.sum()

# Reorder the columns to match the desired format
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug']
pivot_table = pivot_table[month_order]

# Create the headers for the table
headers = ['Row Labels'] + list(pivot_table.columns) + ['Grand Total']

# Create the data for the table
data = [['Intervention'] + list(pivot_table.sum()) + [grand_total]]
data.append(['Jose'] + list(pivot_table.loc['Jose']) + [''])

# Convert the table to a tabulated string
table = tabulate(data, headers, tablefmt='grid')

# Print the tabulated table
print(table)
# Out:
# +--------------+-------+-------+-------+-------+-------+-------+-------+-------+---------------+
# | Row Labels   |   Jan |   Feb |   Mar |   Apr |   May |   Jun |   Jul |   Aug | Grand Total   |
# +==============+=======+=======+=======+=======+=======+=======+=======+=======+===============+
# | Intervention |   276 |   248 |   287 |   213 |   316 |   238 |   191 |   249 | 2620          |
# +--------------+-------+-------+-------+-------+-------+-------+-------+-------+---------------+
# | Jose         |    85 |   104 |   131 |    51 |    67 |    55 |    59 |    61 |               |
# +--------------+-------+-------+-------+-------+-------+-------+-------+-------+---------------+

# %%
# import pandas as pd

# # Load your dataset or replace it with your data
# # df = pd.read_csv('your_data.csv')

# # Filter the dataset for 'ATM Interventions' and 'Technician 4'
# filtered_df = df[(df['Intervention Type'] == 'ATM Interventions') | (df['Technician'] == 'Technician 4')]

# # Extract the month from the 'Created On' column
# filtered_df['Month'] = pd.to_datetime(filtered_df['Created On']).dt.strftime('%b')

# # Pivot the DataFrame to get the counts of interventions per technician and month
# pivot_table = filtered_df.pivot_table(index='Technician', columns='Month', aggfunc='size', fill_value=0)

# # Calculate the grand total by summing all the values in the pivot_table
# grand_total = pivot_table.values.sum()

# # Reorder the columns to match the desired format
# month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug']
# pivot_table = pivot_table[month_order]

# # Create a list of lists to represent the table rows
# table_data = [
#     ["Row Labels", "Rodrigues", "Seychelles", "Zone 1 (Port-Louis)", "Zone 2 (Lower Plaines Wilhems & Black-River)",
#      "Zone 3 (Upper Plaines Wilhems & South)", "Zone 4 (North&East)", "Undefined", "Grand Total"],
#     ["ATM Interventions"] + pivot_table.sum().tolist() + [grand_total],
#     ["Technician 4"] + pivot_table.loc['Technician 4'].tolist() + ['']
# ]

# # Create a list of months
# months = list(pivot_table.columns)

# # Iterate through the months and create rows for each month
# for month in months:
#     table_data.append([month])
#     for tech in pivot_table.index:
#         table_data.append([tech] + [pivot_table.loc[tech, month]] + [''])

# # Print the table
# for row in table_data:
#     print("\t".join([str(val) for val in row]))

# %% [markdown]
# # Total number of Interventions status per month

# %%
import pandas as pd

# Assuming your dataset is named 'df'
# Replace column names as needed
columns_to_select = ['Created On', 'Status']
selected_df = df[columns_to_select]

# Extract the month from the 'Created On' column
selected_df['Month'] = selected_df['Created On'].dt.strftime('%b')

# Pivot the DataFrame to get the counts of each status per month
pivot_table = selected_df.pivot_table(index='Status', columns='Month', aggfunc='size', fill_value=0)

# Calculate the 'Grand Total' by summing the counts across all months
pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# Reorder the columns to match the desired format
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Grand Total']
pivot_table = pivot_table[month_order]

# Display the pivot table
print(pivot_table)
# Out:
# Month                Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Grand Total
# Status
# Assigned              84   62   79  170  228  143  171  175         1302
# Closed               312  306  495  278  230  334  227  186         3025
# InProgress             0    0    2    0    2    0    1    0            6
# Resolution Rejected    0    1    2    0    0    0    0    0            5
# Resolved - Notified    0    0    0    0    4    0    0    0            4

# %%
import pandas as pd

# Assuming your dataset is named 'df'
# Replace column names as needed
columns_to_select = ['Created On', 'Technician', 'Status']
selected_df = df[columns_to_select]

# Extract the month from the 'Created On' column
selected_df['Month'] = selected_df['Created On'].dt.strftime('%b')

# Pivot the DataFrame to get the counts of each status per technician and month
pivot_table = selected_df.pivot_table(index=['Technician', 'Status'], columns='Month', aggfunc='size', fill_value=0)

# Calculate the 'Grand Total' by summing the counts across all months for each technician
pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# Calculate the 'Final Total' by summing the counts across all technicians for each month
final_total = pivot_table.sum().rename('Final Total')

# Append the 'Final Total' row to the pivot table
pivot_table = pivot_table.append(final_total)

# Reorder the columns to match the desired format
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Grand Total']
pivot_table = pivot_table[month_order]

# Display the pivot table
print(pivot_table)
# Out:
# Month                             Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  \
# (Alvin, Assigned)                   4    1    0    0    0    0    0    0
# (Alvin, Closed)                     0    0    0    0    0    0    0    0
# (Antoine, Assigned)                 4    0    1    0    0    0    0    0
# (Antoine, Closed)                   5    3    1    0    1    0    2    0
# (Burty, Assigned)                   0    1    1    0    2    0    0    0
# (Burty, Closed)                    20   22   43   24   19   27    0    0
# (Chrisler, Assigned)                0    0    0    9   30   10   12   19
# (Daniel, Assigned)                 49   37   14   72   84   65   79   62
# (Daniel, Closed)                    9   38   80    7    6   32    3    3
# (Francois, Assigned)                0    0    0    0    8    0    0    0
# (Francois, Closed)                  8    5    6    8   14    3    2    1
# (Gaspard, Assigned)                 0    0    0    0    1    0    5    0
# ...

# %% [markdown]
# # Closed

# %%
import pandas as pd

# Assuming your dataset is named 'df'
# Replace column names as needed
columns_to_select = ['Created On', 'Technician', 'Status']

# Filter the DataFrame to include only 'Closed' status incidents
selected_df = df[df['Status'] == 'Closed'][columns_to_select]

# Extract the month from the 'Created On' column
selected_df['Month'] = pd.to_datetime(selected_df['Created On']).dt.strftime('%b')

# Pivot the DataFrame to get the counts of each status per technician and month
pivot_table = selected_df.pivot_table(index=['Technician', 'Status'], columns='Month', aggfunc='size', fill_value=0)

# Calculate the 'Grand Total' by summing the counts across all months for each technician
pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# Calculate the 'Final Total' by summing the counts across all technicians for each month
final_total = pivot_table.sum().rename('Final Total')

# Append the 'Final Total' row to the pivot table
pivot_table = pivot_table.append(final_total)

# Reorder the columns to match the desired format
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Grand Total']
pivot_table = pivot_table[month_order]

# Display the pivot table
print(pivot_table)
# Out:
# Month                   Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Grand Total
# (Alvin, Closed)           0    0    0    0    0    0    0    0            1
# (Antoine, Closed)         5    3    1    0    1    0    2    0           22
# (Burty, Closed)          20   22   43   24   19   27    0    0          155
# (Daniel, Closed)          9   38   80    7    6   32    3    3          224
# (Francois, Closed)        8    5    6    8   14    3    2    1           53
# (Gaspard, Closed)        26   10   39   46   23   16   16    5          206
# (Ghislain, Closed)        0    0    7   11    4    5    4    0           40
# (Jean Bernard, Closed)   65   61   90   62   56  118   84   54          769
# (Jean Jacques, Closed)    1    0    0    0    0    0    0    0            1
# (Jean Paul, Closed)      26   10   40   39   23   20   23   39          260
# (Joevani, Closed)        13    0    0    0    0    0    3    0           20
# ...

# %%
import pandas as pd

# Assuming your dataset is named 'df'
# Replace column names as needed
columns_to_select = ['Created On', 'Technician', 'Status']

# Filter the DataFrame to include only 'Closed' status incidents
selected_df = df[df['Status'] == 'Closed'][columns_to_select]

# Extract the month from the 'Created On' column
selected_df['Month'] = pd.to_datetime(selected_df['Created On']).dt.strftime('%b')

# Pivot the DataFrame to get the counts of each status per technician and month
pivot_table = selected_df.pivot_table(index=['Technician', 'Status'], columns='Month', aggfunc='size', fill_value=0)

# Calculate the 'Grand Total' by summing the counts across all months for each technician
pivot_table['Grand Total'] = pivot_table.sum(axis=1)

# Calculate the 'Final Total' by summing the counts across all technicians for each month
final_total = pivot_table.sum().rename('Final Total')

# Append the 'Final Total' row to the pivot table
pivot_table = pivot_table.append(final_total)

# Reorder the columns to match the desired format
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Grand Total']
pivot_table = pivot_table[month_order]

# Sort the DataFrame by the 'Grand Total' column in descending order
pivot_table = pivot_table.sort_values(by='Grand Total', ascending=False)

# Display the pivot table
print(pivot_table)
# Out:
# Month                   Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Grand Total
# Final Total             312  306  495  278  230  334  227  186         3025
# (Jose, Closed)           81  100  123   50   55   49   57   60          800
# (Jean Bernard, Closed)   65   61   90   62   56  118   84   54          769
# (michel, Closed)         58   57   66   31   29   63   33   22          471
# (Jean Paul, Closed)      26   10   40   39   23   20   23   39          260
# (Daniel, Closed)          9   38   80    7    6   32    3    3          224
# (Gaspard, Closed)        26   10   39   46   23   16   16    5          206
# (Burty, Closed)          20   22   43   24   19   27    0    0          155
# (Francois, Closed)        8    5    6    8   14    3    2    1           53
# (Ghislain, Closed)        0    0    7   11    4    5    4    0           40
# (Antoine, Closed)         5    3    1    0    1    0    2    0           22
# ...

# %% [markdown]
# # Total number of Interventions per each Technician

# %%
# Filter the dataset for 'Closed' incidents
closed_incidents = df[df['Status'] == 'Closed']

# Group the data by Technician and count unique Incidents
technician_interventions = closed_incidents.groupby('Technician')['Incident Id'].nunique()

# Sort the results in descending order
technician_interventions = technician_interventions.sort_values(ascending=False)

# Print or display the sorted result
print(technician_interventions)
# Out:
# Technician
# Jose            790
# Jean Bernard    746
# michel          469
# Jean Paul       226
# Daniel          221
# Gaspard         199
# Burty           149
# Francois         50
# Ghislain         37
# Antoine          21
# Joevani          18
# Zaid              2
# Alvin             1
# Jean Jacques      1
# Yoven             1
# Name: Incident Id, dtype: int64

# %% [markdown]
# # Scatter Plot of Number of Incidents by Month and Geo

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already loaded your dataset into a DataFrame called df

# Group the data by 'Month' and 'Geo' and count the number of incidents
geo_month_counts = df.groupby(['Month', 'Geo']).size().unstack().fillna(0)

# Plot the scatter plot
for geo in geo_month_counts.columns:
    plt.scatter(geo_month_counts.index, geo_month_counts[geo], label=geo)

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Number of Incidents')
plt.title('Number of Incidents by Month and Geo')
plt.legend(title='Geo', loc='upper right')

# Show the plot
plt.show()

# %%
custom_month_order = ['Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul']

# Reorder the 'Month' column based on the custom_month_order
df['Month'] = pd.Categorical(df['Month'], categories=custom_month_order, ordered=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already loaded your dataset into a DataFrame called df

# Convert 'Created On' to 'Month' and format it to show only the month abbreviation
df['Month'] = pd.to_datetime(df['Created On']).dt.strftime('%b')

# Group the data by 'Month' and 'Geo' and count the number of incidents
geo_month_counts = df.groupby(['Month', 'Geo']).size().unstack().fillna(0)

# Create a color map for the different Geo values
colors = {'Mauritius': 'red', 'Seychelles': 'blue', 'Rodrigues': 'green'}

# Plot the scatter plot for each Geo
for geo, color in colors.items():
    plt.scatter(geo_month_counts.index, geo_month_counts[geo], label=geo, c=color, alpha=0.6, s=50)

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Number of Incidents')
plt.title('Number of Incidents by Month and Geo')
plt.legend(title='Geo', loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# # Scatter Plot of Number of Incidents by Month and Geo with their Model No

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already loaded your dataset into a DataFrame called df

# Convert 'Created On' to 'Month' and format it to show only the month abbreviation
df['Month'] = pd.to_datetime(df['Created On']).dt.strftime('%b')

# Define the custom order of months
custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Set the 'Month' column data type and order
df['Month'] = pd.Categorical(df['Month'], categories=custom_month_order, ordered=True)

# Group the data by 'Month' and 'Geo' and count the number of incidents
geo_month_counts = df.groupby(['Month', 'Geo']).size().unstack().fillna(0)

# Create a color map for the different Geo values
colors = {'Mauritius': 'red', 'Seychelles': 'blue', 'Rodrigues': 'green'}

# Plot the scatter plot for each Geo
for geo, color in colors.items():
    plt.scatter(geo_month_counts.index, geo_month_counts[geo], label=geo, c=color, alpha=0.6, s=50)

    # Add 'Model No' annotations on top of the dots (only for available data points)
    for i, txt in enumerate(df[df['Geo'] == geo]['Model No']):
        if i < len(geo_month_counts):
            plt.annotate(txt, (geo_month_counts.index[i], geo_month_counts[geo].iloc[i]), ha='center')

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Number of Incidents')
plt.title('Number of Incidents by Month and Geo')
plt.legend(title='Geo', loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# # Scatter Plot of Number of Incidents by Month and Geo with their Customer

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already loaded your dataset into a DataFrame called df

# Convert 'Created On' to 'Month' and format it to show only the month abbreviation
df['Month'] = pd.to_datetime(df['Created On']).dt.strftime('%b')

# Define the custom order of months
custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Set the 'Month' column data type and order
df['Month'] = pd.Categorical(df['Month'], categories=custom_month_order, ordered=True)

# Group the data by 'Month' and 'Geo' and count the number of incidents
geo_month_counts = df.groupby(['Month', 'Geo']).size().unstack().fillna(0)

# Create a color map for the different Geo values
colors = {'Mauritius': 'red', 'Seychelles': 'blue', 'Rodrigues': 'green'}

# Plot the scatter plot for each Geo
for geo, color in colors.items():
    plt.scatter(geo_month_counts.index, geo_month_counts[geo], label=geo, c=color, alpha=0.6, s=50)

    # Add 'Customer' annotations on top of the dots (only for available data points)
    for i, txt in enumerate(df[df['Geo'] == geo]['Customer']):
        if i < len(geo_month_counts):
            plt.annotate(txt, (geo_month_counts.index[i], geo_month_counts[geo].iloc[i]), ha='center', rotation=45)

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Number of Incidents')
plt.title('Number of Incidents by Month and Geo')
plt.xticks(rotation=90)  # Rotate month labels by 90 degrees
plt.legend(title='Geo', loc='upper right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# import matplotlib.pyplot as plt
# import pandas as pd

# # Convert "ATM Installation Date" to datetime with errors='coerce'
# df['ATM Installation Date'] = pd.to_datetime(df['ATM Installation Date'], format='%d/%m/%Y', errors='coerce')

# # Define colors for different geographical locations
# colors = {'Mauritius': 'red', 'Seychelles': 'blue', 'Rodrigue': 'green'}

# # Scatter plot
# plt.figure(figsize=(10, 6))

# for geo, color in colors.items():
#     geo_data = df[df['Geo'] == geo]
#     plt.scatter(geo_data['ATM Installation Date'], geo_data['Travel Time'], label=geo, c=color, alpha=0.6, s=50)

# # Highlight the customer with a different marker
# customer_data = df[df['Customer'] == 'Bank 11']
# plt.scatter(customer_data['ATM Installation Date'], customer_data['Travel Time'], label='Customer', c='black', marker='x', s=100)

# plt.xlabel("ATM Installation Date")
# plt.ylabel("Travel Time")
# plt.title("Scatter Plot of Travel Time vs. ATM Installation Date")
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# # Extracting months from DB

# %%
date_columns = ['Created On', 'Reported On', 'Start DateTime', 'End DateTime']
date_format = '%d/%m/%Y'  # Assuming the date format is 'dd/mm/yyyy'

for col in date_columns:
    df[col] = pd.to_datetime(df[col], format=date_format, errors='coerce')

# Extract unique months
df['Month'] = df['Created On'].dt.to_period('M')
unique_months = df['Month'].sort_values().unique()
print(unique_months)
# Out:
# <PeriodArray>
# ['2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06', '2022-07',
#  '2022-08', '2022-09', '2022-10', '2022-11', '2022-12', '2023-01', '2023-02',
#  '2023-03', '2023-04', '2023-05', '2023-06', '2023-07', '2023-08']
# Length: 20, dtype: period[M]

# %%
# Extract unique months without the date component
df['Month'] = df['Created On'].dt.to_period('M').dt.to_timestamp()
unique_months = df['Month'].dt.strftime('%Y-%m').sort_values().unique()
print(unique_months)
# Out:
# ['2022-01' '2022-02' '2022-03' '2022-04' '2022-05' '2022-06' '2022-07'
#  '2022-08' '2022-09' '2022-10' '2022-11' '2022-12' '2023-01' '2023-02'
#  '2023-03' '2023-04' '2023-05' '2023-06' '2023-07' '2023-08']

# %%
# Extract unique months and format them as "Jan," "Feb," etc.
df['Month'] = df['Created On'].dt.strftime('%b %Y')
unique_months = df['Month'].sort_values().unique()
print(unique_months)
# Out:
# ['Apr 2022' 'Apr 2023' 'Aug 2022' 'Aug 2023' 'Dec 2022' 'Feb 2022'
#  'Feb 2023' 'Jan 2022' 'Jan 2023' 'Jul 2022' 'Jul 2023' 'Jun 2022'
#  'Jun 2023' 'Mar 2022' 'Mar 2023' 'May 2022' 'May 2023' 'Nov 2022'
#  'Oct 2022' 'Sep 2022']

# %%
# Extract unique months without the year and format them as "Jan," "Feb," etc.
df['Month'] = df['Created On'].dt.strftime('%b')
unique_months = df['Month'].sort_values().unique()
print(unique_months)
# Out:
# ['Apr' 'Aug' 'Dec' 'Feb' 'Jan' 'Jul' 'Jun' 'Mar' 'May' 'Nov' 'Oct' 'Sep']

# %%
# Define a custom order for months
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Extract unique months without the year
df['Month'] = df['Created On'].dt.strftime('%b')
unique_months = df['Month'].unique()

# Sort the unique months based on the custom order
unique_months_sorted = sorted(unique_months, key=lambda x: month_order.index(x))

print(unique_months_sorted)
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
